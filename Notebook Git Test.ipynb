# %%
resources:
  jobs:
    dabs_cicd:
      name: dabs_cicd
      trigger:
        pause_status: ${pause_status}
        periodic:
          interval: ${interval}
          unit: ${unit}
      tasks:
        - task_key: printLine
          notebook_task:
            notebook_path: /Workspace/DABs/databricks-dabs/notebooks/PrintLine
            source: WORKSPACE
      queue:
        enabled: true
      parameters:
        - name: workspace
          default: development
      performance_target: PERFORMANCE_OPTIMIZED

# %%
df = spark.read.par(my configuration table)
